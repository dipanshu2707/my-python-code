# %% [markdown]
# ## Inheritance

# %% [markdown]
# - Inheritance is a way of creating a new class from an existing class.

# %%
class Employee:                    # Base class
    def __init__(self,name,age,id):
        self.name = name
        self.age = age
        self.id = id

    def showDetails(self):
        print(f"the name of employee:{self.name} and age is {self.age} and id is {self.id}")


class Programmer(Employee):      # Derived class
    def showLanguage(self):           
        print("the language is java") 


# e = Employee("Rohan Das",22,121)
# e.showDetails()
# e1 = Programmer("himanshu", 20, 122)
# e1.showDetails()
# e1.showLanguage()
m1 = Programmer( "himanshu", 20, 122)
print(m1.showDetails())
m2 = Programmer()
print(m2.showLanguage())
# Out:
# the name of employee:himanshu and age is 20 and id is 122
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 23
#      21 m1 = Programmer( "himanshu", 20, 122)
#      22 print(m1.showDetails())
# ---> 23 m2 = Programmer()
#      24 print(m2.showLanguage())
#
# TypeError: Employee.__init__() missing 3 required positional arguments: 'name', 'age', and 'id'

# %%
class Employee:
    company = "google"
    def show(self):
        print(f"the name is {self.name} and id is {self.id} and salary is {self.salary}")

# class Programmer:
#     company = "google Infotech"
#     def show(self):
#         print(f"the name is {self.name} and id is {self.id} and salary is {self.salary}")

#     def showlanguage(self):
#         print(f"the name is {self.name} and id is {self.id} and salary is {self.salary}")

class Programmer(Employee):
    company = "google Infotech"
    def showLanguage(self):
        print(f"the name is {self.name} and id is {self.id} and salary is {self.salary}")

a = Employee()
b = Programmer()

print(a.company,b.company)
# Out:
# google google Infotech

# %%
class parent:
    def __init__(self, name, age, sex):
        self.name = name
        self.age = age
        self.sex = sex
    def showDetails(self):
        print(f"the name is {self.name} and age is {self.age} and sex is {self.sex}")
class child(parent):
    def __init__(self):
        print("this is child class")
    def details(self,roll):
        print("this is details of child class",roll)
c1 = child()
print(c1.details(24))
c2 = child("manilal",20,"male")
c2.details(24)
c2.showDetails()
# Out:
# this is child class
# this is details of child class 24
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      13 c1 = child()
#      14 print(c1.details(24))
# ---> 15 c2 = child("manilal",20,"male")
#      16 c2.details(24)
#      17 c2.showDetails()
#
# TypeError: child.__init__() takes 1 positional argument but 4 were given

# %% [markdown]
# ### Single Inheritance
#
# - Single inheritance occure when chil class inherite only a single parent class.

# %%
class Animal:
    def sound(self):
        print("Animal make sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks") 

d = Dog()
d.sound()
d.bark()
# Out:
# Animal make sound
# Dog barks

# %% [markdown]
# ### Multiple Inheritance
#
# - Multiple inheritance occurs when the child class inherits from more than one parent classes.

# %%
class Employee:
    company = "ITC"
    name = "Animal"
    def show(self):
        print(f"the name of employee is {self.name} and the company is {self.company}")

class coder:
    language = "java"
    def printLanguage(self):
        print(f"out of all the languages here is your language {self.language}")

class Programmer(Employee,coder):
    company = "ITC Infotech"
    def showLanguage(self):                
        print(f"the name of employee is {self.company} and the language is {self.language}")

b = Programmer()
b.show()

b.printLanguage()
b.showLanguage()
# Out:
# the name of employee is Animal and the company is ITC Infotech
# out of all the languages here is your language java
# the name of employee is ITC Infotech and the language is java

# %% [markdown]
# ### Multilevel Inheritance

# %%
class Employee:
    a = 1

class Programmer(Employee):
    b = 2

class Manager(Programmer):
    c = 3

o = Employee()
print(o.a)  # print the a attribute
#print(o.b) #shows an error as there is no b attribute in empoloyee class

o = Programmer()
print(o.a,o.b)

o = Manager()
print(o.c)
# Out:
# 1
# 1 2
# 3

# %% [markdown]
# #### Super() Method
#
# - Super() method is used to access the methods of a super class in the derived class.

# %%
class Employee:
    def __init__(self):
        print("constructor of Employee")
    a = 1

class Programmer(Employee):
    def __init__(self):
        print("constructor of programmer")
    b = 2

class Manager(Programmer):
    def __init__(self):
        super().__init__()
        print("constructor of manager")
    c = 3

# o = Employee()
# print(o.a)  


# o = Programmer()
# print(o.a,o.b)

o = Manager()
print(o.a,o.b,o.c)
# Out:
# constructor of programmer
# constructor of manager
# 1 2 3

# %% [markdown]
# #### Class Method

# %%
class Employee:
    a = 1

    @classmethod
    def show(cls):
        print(f"the class attribute of a is {cls.a}")

e = Employee()
e.a = 45

e.show()
# Out:
# the class attribute of a is 1

# %% [markdown]
# #### Property Decorators

# %%
class Employee:
    a = 1

    @classmethod
    def show(cls):
        print(f"the class attribute of a is {cls.a}")


    @property
    def name(self): 
        return f"{self.fname} {self.lname}"  
    
    @name.setter
    def name(self,value):
        self.fname = value.split(" ")[0]
        self.lname = value.split(" ")[1]

e = Employee()
e.a = 45

e.name = "Harry Singh"
print(e.name)

e.show()
# Out:
# Harry Singh
# the class attribute of a is 1

# %% [markdown]
# ### Operator Overloading

# %% [markdown]
# - Operator overloading in Python means giving special behavior to operators (such as +, -, *, ==, etc.) when they are used with objects of a custom class.

# %% [markdown]
# | Operator | Special Method  |
# | -------- | --------------- |
# | `+`      | `__add__()`     |
# | `-`      | `__sub__()`     |
# | `*`      | `__mul__()`     |
# | `/`      | `__truediv__()` |
# | `%`      | `__mod__()`     |
# | `==`     | `__eq__()`      |
# | `!=`     | `__ne__()`      |
# | `<`      | `__lt__()`      |
# | `<=`     | `__le__()`      |
# | `>`      | `__gt__()`      |
# | `>=`     | `__ge__()`      |
# | `[]`     | `__getitem__()` |
# | `len()`  | `__len__()`     |

# %%
class Number:
    def __init__(self, n):
        self.n = n

    def __add__(self,num):
        return self.n + num.n  

n = Number(1)
m = Number(2)

print(n+m)
# Out:
# 3

# %% [markdown]
# 1. Create a class (2 D vector) and it to create another class representing a 3D vector.

# %%
class  TwoDVector:
    def __init__(self,i,j):
        self.i = i
        self.j = j

    def show(self):
        print(f"The vector is {self.i}i + {self.j}j")    


class ThreeDVector(TwoDVector):
    def __init__(self,i,j,k):
        super().__init__(i,j)
        self.k = k     

    def show(self):
        print(f"The vector is {self.i}i + {self.j}j + {self.k}k")

a = TwoDVector(1,2)
a.show()

b = ThreeDVector(1,2,3)          
b.show()
# Out:
# The vector is 1i + 2j
# The vector is 1i + 2j + 3k

# %% [markdown]
# 2. create a class 'Peat' from a class 'Animal' and futher create a class 'Dog' from 'Peat'.Add a method 'bark' to class 'Dog'.

# %%
class Animals:
    pass


class Pets(Animals):
    pass


class Dog(Pets):       
    @staticmethod
    def bark():
        print("Bow Bow!")

d = Dog()
d.bark()
# Out:
# Bow Bow!

# %% [markdown]
# 3. Create a class 'Empoyee' and add salary and increment properties to it.

# %%
class Empoyee:
    salary = 234
    increment = 20

    @property
    def salaryAfterIncrement(self):
        return (self.salary + self.salary * (self.increment/100))

    @salaryAfterIncrement.setter
    def salareAfterIncrement(self,salary):
        self.increment = ((salary/self.salary) -1)*100

    #def increment(self,salary):

e = Empoyee()
#print(e.salaryAfterIncrement)



e.salaryAfterIncrement = 280.8
print(e.increment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 20
#      15 e = Empoyee()
#      16 #print(e.salaryAfterIncrement)
# ---> 20 e.salaryAfterIncrement = 280.8
#      21 print(e.increment)
#
# AttributeError: property 'salaryAfterIncrement' of 'Empoyee' object has no setter

# %% [markdown]
# 4. write a class 'complex' to represent complex numbers along  with overloded operators '+' and '*' which adds and multiplies them.

# %%
class Complex:
    def __init__(self,r,i):
        self.r = r
        self.i = i

    def __add__(self, c2):
        return complex(self.r + c2.r, self.i + c2.i)     
    
    def __mul__(self,c2):
        return complex (self.r * c2.r, self.i * c2.i)    
     #def __str__(self):
      #   return f"{self.r} + {self.i}"

c1 = Complex(1,2)
c2 = Complex(4,5)
print(c1 + c2)   
print(c1*c2)
# Out:
# (5+7j)
# (4+10j)

# %%
class Vector:
    def __init__(self,x,y,z):
        self.x = x
        self.y =  y
        self.z = z

    def __add__(self,other):
        result = Vector(self.x + other.x,self.y + other.y,self.z + other.z)     
        return result
    
    def __mul__(self,other):
        result = (self.x * other.x,self.y * other.y,self.z * other.z)
        return result

    def __str__(self):
          return f"Vectonr {self.x},{self.y},{self.z}"

v1 = Vector(1,2,3)
v2 = Vector(4,5,6)
v3 = Vector(7,8,9) #same dimension vector

print(v1+v2)
print(v1*v2)

print(v1 + v3)
print(v1 * v3)
# Out:
# Vectonr 5,7,9
# (4, 10, 18)
# Vectonr 8,10,12
# (7, 16, 27)

# %% [markdown]
# 6. Write __str__() method to print the vector as followes.

# %%
class Vector:
    def __init__(self,x,y,z):
        self.x = x
        self.y =  y
        self.z = z

    def __add__(self,other):
        result = Vector(self.x + other.x,self.y + other.y,self.z + other.z)     
        return result
    
    def __mul__(self,other):
        result = (self.x * other.x,self.y * other.y,self.z * other.z)
        return result

    def __str__(self):
          return f"{self.x}i,{self.y}j,{self.z}k"

v1 = Vector(1,2,3)
v2 = Vector(4,5,6)
v3 = Vector(7,8,9) #same dimension vector

print(v1+v2)
print(v1*v2)

print(v1 + v3)
print(v1 * v3)
# Out:
# 5i,7j,9k
# (4, 10, 18)
# 8i,10j,12k
# (7, 16, 27)
