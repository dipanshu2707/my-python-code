# %% [markdown]
# # VARIBALES  AND  DATATYPE
# ### A varible is a name used to store data (a value) in memory
# `Varible = a container that holds data`
#
# a = 12     variable container to store a value
# b = "harry"  keyword reserved words in python
#
# @s = 32 #invalid due to @ symbol
# ram@ram = 45 #invalid due to @ symbol
# 2sammer = 23 #invalid not start with a digit
# ram ram = 54 #no whild space is allowed to using inside
#
# ## DATATYPE
# - A data type is the type of data (value) store in a variable.
#
# a = 1 #a is an integer
#
# b = 2.45 #b is a float
#
# c = "ram" #c is a string
#
# d = True,False # d is a boolean
#
# e = None # e is a none type variable

# %% [markdown]
# ### ARITHMETIC OPERATORS +,-,*,/etc

# %%
a = 4
b = 8
print(a+b)
print(a-b)
print(a*b)
print(a/b)

# %% [markdown]
# ### Assignment operators =,+=,-=,*=,/=,%= etc

# %%
a = 4-2 #assign 4-2 in a
print(a)
b = 6
b +=4  #incremrnt the value of b by 4 and then assine
print(b)
c = 7
c *=2  # c store in same variable
print(c)
# Out:
# 2
# 10
# 14

# %% [markdown]
# ### Comparison operators ==,>,>=,<,>=,!=

# %%
d = 5<4
print(d)
s = 5>3
print(s)
q = 7>=7
print(q)
w = 8<=5
print(w)
e = 5!=9
print(e)
t = 5!=5
print(t)
u = 3==2
print(u)
# Out:
# False
# True
# True
# False
# True
# False
# False

# %% [markdown]
# ### Logical operators and,or,not.

# %% [markdown]
# ##### Truth table of 'or'

# %%
e = True or False
print("True or False is ",True or False)
print("True or True is ",True or True)
print("False or True is ",False or True)
print("False or False is ",False or False)
# Out:
# True or False is  True
# True or True is  True
# False or True is  True
# False or False is  False

# %% [markdown]
# #### 'And'

# %%
s = True and False
print("True and False is ",True and False)
print("True and True is",True and True)
print("False and True is",False and True)
print("False and False is",False and False)
# Out:
# True and False is  False
# True and True is True
# False and True is False
# False and False is False

# %% [markdown]
# ##### 'Not'

# %%
x = True 
print(not x)

a = 4
b = 9
print(not(a > b))

# %% [markdown]
#    ### Type() function and typecasting

# %% [markdown]
# type() function is used to finde the data type of a given varible in python

# %%
a = 4 
print(type(a)) #class<int>
a = 35.6
print(type(a))
a = 'ram'
print(type(a))
a = "493"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ##### Type casting

# %% [markdown]
# type casting means converting one data type into another

# %%
a = "498"
b = float(a)   # a but the type should be float
t = type(b)
print(t)

a = "427"
b = float(a)
print(type(b))

a = 456.86
b = int(a)
print(type(b))

a = "ram"
b = int(a)
print(type(b))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### input() function

# %% [markdown]
# The input() function is user to take input from the user (keyboard)

# %%
a = input("Enter number 1 : ")
b = input("enter number 2: ")

#print(a)
print("number a is:", a)
print("number b is:",b)
# Out:
# number a is: 2
# number b is: 4

# %%
a = input("enter a num 1")
b = input("enter a num 2")

print(a+b)
# Out:
# 34

# %%
a = int(input("enter a num1"))
b = int(input("enter a num2"))

print(a+b)
# Out:
# 7

# %% [markdown]
# 1 . write a python program to add two numbers

# %%
a = int(input("Enter a number 1"))
b = int(input("Enter a numder 2"))

print(a+b)

# %% [markdown]
# 2. write a python to finde remainder when a number is divided by Z

# %%
a = 34
b =5
print("remainder when a is divided by b is",a%b)
# Out:
# remainder when a is divided by b is 4

# %% [markdown]
# 3. check the type of variable assigned using input() function

# %%
a = input("Enter the value of a:")
print(type(a))

b = int(input('enter the value of b:'))
print(type(b))

# %% [markdown]
#  4. use comparison operator to find out whether a given variable a is greter than 'b'or not take a = 34 and b =50

# %%
a = 34
b = 50
print(a>b)

a = int(input("Enter number 1"))
b = int(input("enter number 2"))
print("a is greater then b is",a>b)
# Out:
# False
# a is greater then b is True

# %% [markdown]
# 5. write a python program to find an average of two numbers entered by the user

# %%
a = 45.6
b = 35

print((a+b)/2)

a = int(input("enter number 1:"))
b = int(input("enter number 2:"))

print("the average of these two number is",(a+b)/2)
# Out:
# 40.3
# the average of these two number is 4.0

# %% [markdown]
# 6. write a python program to calculate the square of a number entered by the user

# %%
a =  int(input("Enter your number:"))

print("the square of the number is ",a*a)

a = 3
print(a**2)  #^ not valide

# %% [markdown]
# 7. write a python program to store your and name and age and print them.

# %%
a = "harry"
b = "22"

print(a,b)
# Out:
# harry 22

# %% [markdown]
# 8. WAP a python program to declare two variables and print their sum.

# %%
a = 23
b = 12
#sum =(a+b)

print(a+b)
# Out:
# 35

# %% [markdown]
# 9. WAP to check the data type of different variables.

# %%
a = 23
b = "sew"
c = 235.6
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# 10.WAP to assign multiple values in one line and print them.

# %%
a,b,c,d = 1,4,6,8

print(a,b,c,d)
# Out:
# 1 4 6 8

# %% [markdown]
# 11.WAP to swap two varibles without using third variable.

# %%
a,b = 1,2
a,b = b,a

print(a,b)
# Out:
# 2 1

# %% [markdown]
# WAP to perfome add,sub and mult.

# %%
a = 2
b = 5

print(a+b)
print(a-b)
print(a*b)
# Out:
# 7
# -3
# 10

# %%
a = 12

print(a>10)
# Out:
# True

# %% [markdown]
# WAP to check if two numbers are equal or not.

# %%
a = 5
b = 5

print(a==b)
print(a!=b)
# Out:
# True
# False

# %% [markdown]
# WAP to using logical operators to check if a number lies between 10 and 50.

# %%
a = 20

print(a>10,a<50)
# Out:
# True True

# %% [markdown]
# WAP to check if a number is divisible by both 3 and 5.

# %%
a = 15
#a/3
#a/5

print(a%3==0 and a%5==0)
#print(a/3,a/5)
# Out:
# True

# %% [markdown]
# Type function & type casting
#
#
# 1.WAP to check the type of a variable.

# %%
a = 25 
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# 2. WAP to convert int into float.

# %%
a = 23
b = float(a)
print(b)
#print(type(b))
# Out:
# 23.0
# <class 'float'>

# %% [markdown]
# 3. wAP to take string input and convert into int and add 20.

# %%
a = input("enter no")
b = int(a)

print(b + 20)
# Out:
# 43

# %% [markdown]
# 4.WAP to convert float into integer and print both value.

# %%
a = 23.0
b = int(a)

print(a)
print(b)
# Out:
# 23.0
# 23

# %% [markdown]
# #Input Function
#
# 1.WAP to take name as input and print it.

# %%
a = input("enter your name")

print(a)
# Out:
# dipanshu

# %% [markdown]
# 2.WAP to take two numbers as input and print their sum.

# %%
a = int(input("enter first number"))
b = int(input("enter second number"))

print(a+b)
# Out:
# 6

# %% [markdown]
# 3.WAP to take age input and check if eligible for voting.

# %%
a = int(input("Enter your age"))
if a >= 18:
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# 4.WAP to take number input and print its square.

# %%
a = int(input("Enter number"))

print(a*a)
# Out:
# 4
