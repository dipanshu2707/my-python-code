# %% [markdown]
# ### Conditional operation

# %%
a = int(input("enter your age: "))

if(a>=18):
    print("you are above the age of consent")

elif(a<0):
    print ("you are entering an invalid negative age")

elif(a==0):
    print("you are entering 0 which is not a valid age")    

else:
    print("you are not above the age of consent")

print("end of pr ogram")
# Out:
# you are entering 0 which is not a valid age

# %% [markdown]
# - write a program to print yes when the age entered by the user is greater than equal to 18.

# %%
a = int(input("enter your age"))

if(a>=18):
    print("yes")

else:
    print("no")
# Out:
# no

# %% [markdown]
#  #### Relation Operators

# %% [markdown]
# - Relation operatons are user to evaluate conditions inside the if statements.
#
#     - ==equals
#     - => greater than/equal
#     - <= lesser than /equal

# %% [markdown]
# #### Logical Operators

# %% [markdown]
# - In python logical operators operate on conditionl statements.
#
#      - and = true if both operators and true else false
#      - or = true if least one operators is true or else false
#      - not = inverts true to false & false to true

# %%
a = int(input("enter your age "))

if(a%2 == 0): # if statement no 1
    print("a is even number")

if(a>=18): # if statement no 2
    print("you are above the age of consent")

elif(a<0):
    print("you are entering an invalid negative age")

else:
    print("you are below the age of consent")

print("end of program")
# Out:
# you are below the age of consent
# end of program

# %%
num = int(input("enter a number"))

if (num>0):
    print("positive nuber")

    if (num%2):
        print("it is even")

    else:
        print("it is odd")

elif(num<0):
    print("negative number")   

else:
    print("number is zero")
# Out:
# positive nuber
# it is odd

# %% [markdown]
# 1. write a program to find the greatest of four numbers entered by the user.

# %%
a1 = int(input("enter number 1"))
a2= int(input("enter number 2"))
a3 = int(input("enter number 3"))
a4 = int(input("enter number 4"))

if(a1>a2 and a1>a3 and a1>a4):
    print("greatest number is a1",a1)

elif(a2>a1 and a2>a3 and a2>a4):
    print("greatest number is a2",a2)    
    
elif(a3>a1 and a3>a2 and a3>a4):
    print("greatest number is a3",a3) 

elif(a4>a1 and a4>a2 and a4>a3):
    print("greatest number is a4",a4)
# Out:
# greatest number is a4 5

# %%
marks1 = int(input("enter marks 1"))
marks2  = int(input("enter marks 2"))
marks3 = int(input("enter marks 3"))

total_percentage =(100*(marks1 + marks2 + marks3))/300

if(total_percentage>=40 and marks1>33 and marks2>33 and marks3>33 ):
    print("you are pass",total_percentage)

else:
    print("you are failed",total_percentage)
# Out:
# you are pass 66.0

# %% [markdown]
# 3. A spam comment is defined as a text containing following keyword:
# "Make a lot of money","buy now","subscribe this","click this".write a program to detect these spame.

# %%
p1 ="Make a lot of money"
p2 ="buy now"
p3 ="subscribe this"
p4 ="click this"

message = input("Enter your comment")

if(p1 in message or p2 in message or p3 in message or p4 in message):
    print("this is a spam")

else:
    print("this is not a spam")
# Out:
# this is a spam

# %%
sen = "dipanshu is a very good boy"

words = sen.split()
print(words)
# Out:
# ['dipanshu', 'is', 'a', 'very', 'good', 'boy']

# %% [markdown]
# 4. write a program to find whether a given username contains less than 10 characters or not.

# %%
username = input("Enter username")

if(len(username)<10):
    print("your username less than 10 characters")

else:
    print("your username more then 10 characters ")
# Out:
# your username more then 10 characters

# %% [markdown]
# 5. write a program which finds out whether a given name is present in a list or not.

# %%
list = ["harry","ram","rohan","shubham","kalu","roshni"]

name = input("enter your name ")

if(name in list):
    print("your name is in the list")

else:
    print("your name is not in the list")
# Out:
# tour name is not in the list

# %% [markdown]
# 6. write a program which finde out whether a given name is present in a list or not.
# 90-100 = Ex,
# 80-90 = A,
# 70-80 = B,
# 60-70 = C,
# 50-60 = D,
# <50 = F,

# %%
marks = int(input("enter your marks"))

if(marks<=100 and marks>=90):
    grade = "Ex"

elif(marks<=90 and marks>=80):
    grade = "A"

elif(marks<=80 and marks>=70):
    grade = "B"

elif(marks<=70 and marks>=60):
    grade = "C"

elif(marks<=60 and marks>=50):
    grade = "B" 

elif(marks<=50):
    grade = "F" 

print("your grade is :",grade)
# Out:
# your grade is : F

# %%
def percentage_grade(marks: int):
    # int(input("Enter Yor Number"))
    grade=""
    if(marks<=100 and marks>=90):
        grade = "Ex"

    elif(marks<=90 and marks>=80):
        grade = "A"

    elif(marks<=80 and marks>=70):
        grade = "B"

    elif(marks<=70 and marks>=60):
        grade = "C"

    elif(marks<=60 and marks>=50):
        grade = "B" 

    elif(marks<=50):
        grade = "F"
    
    return grade

# %%
percentage_grade(55)
# Out:
# 'B'

# %%
percentage_grade(97)
# Out:
# 'Ex'

# %%
user_1 = int(input("enter your number")) 
user_2 = int(input("enter your number")) 
user_3 = int(input("enter your number")) 
user_4 = int(input("enter your number"))

# greatest_number = 0

if(user_1>user_2 and user_1>user_3 and user_1>user_4):
    # greatest_number=user_1
    print('greates number USER 1: ', user_1)
elif(user_2>user_1 and user_2>user_3 and user_3>user_4):
    # greatest_number=user_2
    print('greates number USER 2: ', user_2)

elif(user_3>user_1 and user_3>user_2 and user_3>user_4):
    # greatest_number=user_3
    print('greates number USER 3: ', user_3)
else:
    # greatest_number=user_4
    print('greates number USER 4: ', user_4)

print(user_1)
print(user_2)
print(user_3)
print(user_4)
#print(greatest_number)
# Out:
# greates number USER 4:  4
# 1
# 2
# 3
# 4

# %% [markdown]
# 7. write a program to find out whether a given post is talking about "harry" or not.

# %%
post = input("entry yuor post")

if("harry in post"):
    print("this post is talking about harry" )

else:
    print("this post is not talking about harry")
# Out:
# this post is talking about harry

# %%
post = input("entry yuor post")

if("Harry".lower() in post.lower()):
    print("this post is talking about harry" )

else:
    print("this post is not talking about harry")
# Out:
# this post is talking about harry
