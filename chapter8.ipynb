# %% [markdown]
# ### Functions & Recursions

# %% [markdown]
# - A function is a group of statements perfoming a specific task.
#
# - A function in python is a block of code used to perform a specific task.
#
# - you create a function using the def keyword:

# %%
def func1():
    print("hello")

# %%
a = int(input("enter your number:"))
b = int(input("enter your number:"))
c = int(input("enter your number:"))

average = (a+b+c)/3
print(average)
# Out:
# 2.0

# %%
# Function definition

def avg():
    a = int(input("enter your number:"))
    b = int(input("enter your number:"))
    c = int(input("enter your number:"))

    average = (a+b+c)/3
    print(average)

# Function call
avg()   
avg()   
avg()   
avg()   
avg()
# Out:
# 6.0
# 5.0
# 8.666666666666666
# 6.333333333333333
# 7.666666666666667

# %% [markdown]
# write a program to greet a user with "good day" using functions.

# %%
def goodDay():
    print("Good Day")

goodDay()
# Out:
# Good Day

# %% [markdown]
# ### Types of function
#
# - There are two types of function

# %% [markdown]
# - Built in functions(Already present )
#    - Ex print(),len(),type()
#
# - User defined function (Defined the user)

# %% [markdown]
# ##### Functions with arguments

# %%
def goodDay(name):
    print("good Day," + name)

goodDay("Harry")
# Out:
# good Day,Harry

# %%
def goodDay(name, ending):
    print("good Day," + name)
    print(ending)

goodDay(" Harry ", "Thank you")
goodDay("Rohan", "Thank you")
goodDay("Divya", "thanks")
# Out:
# good Day, Harry
# Thank you
# good Day,Rohan
# Thank you
# good Day,Divya
# thanks

# %%
def goodDay(name, ending):
    print("good Day," + name)
    print(ending)
    return "ok"

a = goodDay(" Harry ", "Thank you")
# Out:
# good Day, Harry
# Thank you

# %% [markdown]
# #### Default parmeter value

# %% [markdown]
# - we can have a value as default as default argument in a functiom.

# %%
def goodDay(name, ending= "thank you"):
    print(f"good Day,  {name}")
    print(ending)

goodDay("Harry", "Thanks")
goodDay("Ram")
# Out:
# good Day,  Harry
# Thanks
# good Day,  Ram
# thank you

# %% [markdown]
# ### Recurion

# %% [markdown]
# - Recurion is a function which calls itself.
#
# - It is used to directly use a mathematical formula as function.
#
#
#
#
#      - factorial(0) = 1
#      - factorial(1) = 1
#      - factorial(2) = 2x1
#      - factorial(2) = 3x2x1
#     - factorial(n) = n x n-1 x....3x2x1
#
# - factorial(n) = n * factorial(n-1)

# %%
n = int(input("Enter a number:"))
def factorial(n):
    if(n==1 or n==0):
        return 1
    return n * factorial(n-1)

print(f"{factorial(n)}")
# Out:
# 720

# %%
def greatest(a, b, c):


    if(a>b and a>c):
        print(a)
    elif(b>a and b>c):
        print(b)
    elif(c>a and c>b):
        print(c)

a = int(input("enter your number:"))
b = int(input("enter your number:"))
c = int(input("enter your number:"))
        

print(greatest(a,b,c))
# Out:
# 7
# None

# %% [markdown]
# 2. write a python program using function to convert celsius to fahrenhit.

# %%
#f = int(input("enter temp in F"))
def celsius_to_fahrenhit(f):
    return 5*(f-32)/9


f = int(input("enter temp in F"))
print(celsius_to_fahrenhit(f))

#print(f"{celsius_to_fahrenhit} C")
#celsius_to_fahrenhit(f)
# Out:
# 40.0

# %%
print("a")
print("b")
print("c", end="")
print("d")
print("e")
# Out:
# a
# b
# cd
# e

# %% [markdown]
# 4. write a recursive function to calculate the sum of first n natural numbers.
#
# '''
# sum(1) = 1
# sum(2) = 1 + 2
# sum(3)=  1+2+3
# sum(n) = 1+2+3+4....n-1+n
# sum(n) = sum(n-1) + n
# '''

# %%
def sum(n):
    if(n==1):
        return 1
    return sum(n-1) + n
print(sum(5))
# Out:
# 15

# %%
def pattern(n):

    if(n==0):
        return
    print("*" * n)
    pattern(n-1)
#n = int(input("enter a number"))
pattern(5)
# Out:
# *****
# ****
# ***
# **
# *

# %%
def inch_to_cms(inch):
    return inch * 2.54

n = int(input("entre value un inches"))
print(f"the corresponding value in cms is {inch_to_cms(n)}")
# Out:
# the corresponding value in cms is 20.32

# %% [markdown]
# write a python function to remove a given word from a list ad strip it at the same.

# %%
def rem(l,word):
    for item in l:
        l.remove(word)
        return l
    
l = ["ram","roham","shumbham","an"]

print(rem(l,"an"))
# Out:
# ['ram', 'roham', 'shumbham']

# %%
def rem(l,word):
    n = []
    for item in l:
        if not(item == word):
            n.append(item.strip(word))
    return n
        
    
l = ["ram","rohan","shumbham","an"]

print(rem(l,"an"))
# Out:
# ['ram', 'roh', 'shumbham']

# %%
def multiply(n):
    for i in range(1,11):
        print(f"{n} x {i} {n*i}")

print(multiply(5))
# Out:
# 5 x 1 5
# 5 x 2 10
# 5 x 3 15
# 5 x 4 20
# 5 x 5 25
# 5 x 6 30
# 5 x 7 35
# 5 x 8 40
# 5 x 9 45
# 5 x 10 50
# None
